# %%
import numpy as np
import matplotlib.pyplot as plt
import json
import networkx as nx

# %%
dubs_id = 1610612744

players = {}
ids = {}
teams = {}
with open("data/players.json") as f:
    data = json.load(f)

for row in data:
    if (row['lastName'] == ""):
        name = row["firstName"]
    else:
        name = row['lastName']+", "+row["firstName"]
    iden = str(row['playerId'])
    players[name] = iden
    ids[iden] = name
    teams[iden] = row['teamId']

# %%
G = nx.DiGraph()
widths = []
labels = {}
for name in players:
    iden = players[name]
    if(teams[iden] != dubs_id):
        continue
    with open("data/"+players[name]+"-passing.json", "r") as f:
        data = json.load(f)
    labels[iden] = name
    for key in data:
        if (teams[key] != dubs_id or data[key][0] < 3.5):
            continue
        widths.append(data[key][0])
        G.add_edge(iden, key, weight = data[key][0])
        labels[key] = ids[key]

widths = np.array(widths)/4.0


print(G.number_of_nodes())
print(len(labels))
print(G.number_of_edges())
print(len(widths))

plt.figure(figsize=(10,10))
pos = nx.circular_layout(G)
nx.draw_networkx_edges(G, pos, width=widths)
nx.draw_networkx_nodes(G, pos, node_size=50)
nx.draw_networkx_labels(G,pos,labels, font_size=6)
# Out:
# 11
# 15
# 33
# 33
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-3995c8a193e1> in <module>()
#      28 nx.draw_networkx_edges(G, pos, width=widths)
#      29 nx.draw_networkx_nodes(G, pos, node_size=50)
# ---> 30 nx.draw_networkx_labels(G,pos,labels, font_size=6)
#
# /usr/local/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py in draw_networkx_labels(G, pos, labels, font_size, font_color, font_family, font_weight, alpha, bbox, ax, **kwds)
#     792     text_items = {}  # there is no text collection so we'll fake one
#     793     for n, label in labels.items():
# --> 794         (x, y) = pos[n]
#     795         if not is_string_like(label):
#     796             label = str(label)  # this makes "1" and 1 labeled the same
#
# KeyError: '1627745'
